# %% [markdown]
# # Data Transformation

# %% [markdown]
# The idea of this file is to clean and merge the two dataset that we have fetched from the SWAPI

# %%
import pandas as pd

# %%
swapi_char = pd.read_csv(".\data\swapi_char.csv")
swapi_details = pd.read_csv(".\data\swapi_details.csv")
swapi_homeworld = pd.read_csv(".\data\swapi_homeworld.csv")

# %% [markdown]
# ### Concat the two tables to be one table

# %%
df = pd.concat([swapi_char,swapi_details, swapi_homeworld], axis=1)

# %%
df
# Out:
#     uid                   name                                   url  \
# 0     1         Luke Skywalker   https://www.swapi.tech/api/people/1
# 1     2                  C-3PO   https://www.swapi.tech/api/people/2
# 2     3                  R2-D2   https://www.swapi.tech/api/people/3
# 3     4            Darth Vader   https://www.swapi.tech/api/people/4
# 4     5            Leia Organa   https://www.swapi.tech/api/people/5
# 5     6              Owen Lars   https://www.swapi.tech/api/people/6
# 6     7     Beru Whitesun lars   https://www.swapi.tech/api/people/7
# 7     8                  R5-D4   https://www.swapi.tech/api/people/8
# 8     9      Biggs Darklighter   https://www.swapi.tech/api/people/9
# 9    10         Obi-Wan Kenobi  https://www.swapi.tech/api/people/10
# 10   11       Anakin Skywalker  https://www.swapi.tech/api/people/11
# 11   12         Wilhuff Tarkin  https://www.swapi.tech/api/people/12
# 12   13              Chewbacca  https://www.swapi.tech/api/people/13
# 13   14               Han Solo  https://www.swapi.tech/api/people/14
# 14   15                 Greedo  https://www.swapi.tech/api/people/15
# 15   16  Jabba Desilijic Tiure  https://www.swapi.tech/api/people/16
# 16   18         Wedge Antilles  https://www.swapi.tech/api/people/18
# 17   19       Jek Tono Porkins  https://www.swapi.tech/api/people/19
# 18   20                   Yoda  https://www.swapi.tech/api/people/20
# 19   21              Palpatine  https://www.swapi.tech/api/people/21
# 20   22              Boba Fett  https://www.swapi.tech/api/people/22
# 21   23                  IG-88  https://www.swapi.tech/api/people/23
# 22   24                  Bossk  https://www.swapi.tech/api/people/24
# 23   25       Lando Calrissian  https://www.swapi.tech/api/people/25
# 24   26                  Lobot  https://www.swapi.tech/api/people/26
# 25   27                 Ackbar  https://www.swapi.tech/api/people/27
# 26   28             Mon Mothma  https://www.swapi.tech/api/people/28
# 27   29           Arvel Crynyd  https://www.swapi.tech/api/people/29
# 28   30  Wicket Systri Warrick  https://www.swapi.tech/api/people/30
#
#                      name   height     mass hair_color    skin_color  \
# 0          Luke Skywalker      172       77      blond          fair
# 1                   C-3PO      167       75        NaN          gold
# 2                   R2-D2       96       32        NaN         white
# 3             Darth Vader      202      136       none         white
# 4             Leia Organa      150       49      brown         light
# 5               Owen Lars      178      120      brown          grey
# 6      Beru Whitesun lars      165       75      brown         light
# 7                   R5-D4       97       32        NaN         white
# 8       Biggs Darklighter      183       84      black         light
# 9          Obi-Wan Kenobi      182       77     auburn         white
# 10       Anakin Skywalker      188       84      blond          fair
# 11         Wilhuff Tarkin      180  unknown     auburn          grey
# 12              Chewbacca      228      112      brown       unknown
# 13               Han Solo      180       80      brown          fair
# 14                 Greedo      173       74        NaN         green
# 15  Jabba Desilijic Tiure      175        1        358           NaN
# 16         Wedge Antilles      170       77      brown          fair
# 17       Jek Tono Porkins      180      110      brown          fair
# 18                   Yoda       66       17      white         green
# 19              Palpatine      170       75       grey          pale
# 20              Boba Fett      183     78.2      black          fair
# 21                  IG-88      200      140       none         metal
# 22                  Bossk      190      113       none         green
# 23       Lando Calrissian      177       79      black          dark
# 24                  Lobot      175       79       none         light
# 25                 Ackbar      180       83       none  brown mottle
# 26             Mon Mothma      150  unknown     auburn          fair
# 27           Arvel Crynyd  unknown  unknown      brown          fair
# 28  Wicket Systri Warrick       88       20      brown         brown
#
#     eye_color birth_year  ...                          homeworld  \
# 0        blue      19BBY  ...   https://swapi.info/api/planets/1
# 1      yellow     112BBY  ...   https://swapi.info/api/planets/1
# 2        blue        red  ...                                NaN
# 3      yellow    41.9BBY  ...   https://swapi.info/api/planets/1
# 4       brown      19BBY  ...   https://swapi.info/api/planets/2
# 5       light       blue  ...                               male
# 6        blue      47BBY  ...   https://swapi.info/api/planets/1
# 7         red        red  ...                                NaN
# 8       brown      24BBY  ...   https://swapi.info/api/planets/1
# 9        fair  blue-gray  ...                               male
# 10       blue    41.9BBY  ...   https://swapi.info/api/planets/1
# 11       fair       blue  ...                               male
# 12       blue     200BBY  ...  https://swapi.info/api/planets/14
# 13      brown      29BBY  ...  https://swapi.info/api/planets/22
# 14      black      44BBY  ...  https://swapi.info/api/planets/23
# 15  green-tan      brown  ...                             600BBY
# 16      hazel      21BBY  ...  https://swapi.info/api/planets/22
# 17       blue    unknown  ...  https://swapi.info/api/planets/26
# 18      brown     896BBY  ...  https://swapi.info/api/planets/28
# 19     yellow      82BBY  ...   https://swapi.info/api/planets/8
# 20      brown    31.5BBY  ...  https://swapi.info/api/planets/10
# 21        red      15BBY  ...  https://swapi.info/api/planets/28
# 22        red      53BBY  ...  https://swapi.info/api/planets/29
# 23      brown      31BBY  ...  https://swapi.info/api/planets/30
# 24       blue      37BBY  ...   https://swapi.info/api/planets/6
# 25     orange      41BBY  ...  https://swapi.info/api/planets/31
# 26       blue      48BBY  ...  https://swapi.info/api/planets/32
# 27      brown    unknown  ...  https://swapi.info/api/planets/28
# 28      brown       8BBY  ...   https://swapi.info/api/planets/7
#
#    homeworld_name rotation_period  orbital_period  diameter    climate  \
# 0        Tatooine            23.0           304.0   10465.0       arid
# 1        Tatooine            23.0           304.0   10465.0       arid
# 2             NaN             NaN             NaN       NaN        NaN
# 3        Tatooine            23.0           304.0   10465.0       arid
# 4        Alderaan            24.0           364.0   12500.0  temperate
# 5             NaN             NaN             NaN       NaN        NaN
# 6        Tatooine            23.0           304.0   10465.0       arid
# 7             NaN             NaN             NaN       NaN        NaN
# 8        Tatooine            23.0           304.0   10465.0       arid
# 9             NaN             NaN             NaN       NaN        NaN
# 10       Tatooine            23.0           304.0   10465.0       arid
# 11            NaN             NaN             NaN       NaN        NaN
# 12       Kashyyyk            26.0           381.0   12765.0   tropical
# 13       Corellia            25.0           329.0   11000.0  temperate
# 14          Rodia            29.0           305.0    7549.0        hot
# 15            NaN             NaN             NaN       NaN        NaN
# 16       Corellia            25.0           329.0   11000.0  temperate
# 17     Bestine IV            26.0           680.0    6400.0  temperate
# 18        unknown             0.0             0.0       0.0    unknown
# 19          Naboo            26.0           312.0   12120.0  temperate
# 20         Kamino            27.0           463.0   19720.0  temperate
# 21        unknown             0.0             0.0       0.0    unknown
# 22      Trandosha            25.0           371.0       0.0       arid
# 23        Socorro            20.0           326.0       0.0       arid
# 24         Bespin            12.0          5110.0  118000.0  temperate
# 25       Mon Cala            21.0           398.0   11030.0  temperate
# 26      Chandrila            20.0           368.0   13500.0  temperate
# 27        unknown             0.0             0.0       0.0    unknown
# 28          Endor            18.0           402.0    4900.0  temperate
#
#                                    gravity  \
# 0                               1 standard
# 1                               1 standard
# 2                                      NaN
# 3                               1 standard
# 4                               1 standard
# 5                                      NaN
# 6                               1 standard
# 7                                      NaN
# 8                               1 standard
# 9                                      NaN
# 10                              1 standard
# 11                                     NaN
# 12                              1 standard
# 13                              1 standard
# 14                              1 standard
# 15                                     NaN
# 16                              1 standard
# 17                                 unknown
# 18                                 unknown
# 19                              1 standard
# 20                              1 standard
# 21                                 unknown
# 22                           0.62 standard
# 23                              1 standard
# 24  1.5 (surface), 1 standard (Cloud City)
# 25                                       1
# 26                                       1
# 27                                 unknown
# 28                           0.85 standard
#
#                                      terrain surface_water   population
# 0                                     desert             1       200000
# 1                                     desert             1       200000
# 2                                        NaN           NaN          NaN
# 3                                     desert             1       200000
# 4                      grasslands, mountains            40   2000000000
# 5                                        NaN           NaN          NaN
# 6                                     desert             1       200000
# 7                                        NaN           NaN          NaN
# 8                                     desert             1       200000
# 9                                        NaN           NaN          NaN
# 10                                    desert             1       200000
# 11                                       NaN           NaN          NaN
# 12            jungle, forests, lakes, rivers            60     45000000
# 13             plains, urban, hills, forests            70   3000000000
# 14            jungles, oceans, urban, swamps            60   1300000000
# 15                                       NaN           NaN          NaN
# 16             plains, urban, hills, forests            70   3000000000
# 17                     rocky islands, oceans            98     62000000
# 18                                   unknown       unknown      unknown
# 19  grassy hills, swamps, forests, mountains            12   4500000000
# 20                                     ocean           100   1000000000
# 21                                   unknown       unknown      unknown
# 22      mountains, seas, grasslands, deserts       unknown     42000000
# 23                        deserts, mountains       unknown    300000000
# 24                                 gas giant             0      6000000
# 25                    oceans, reefs, islands           100  27000000000
# 26                           plains, forests            40   1200000000
# 27                                   unknown       unknown      unknown
# 28                 forests, mountains, lakes             8     30000000
#
# [29 rows x 21 columns]

# %%
df = df.iloc[:, :3].join(df.iloc[:, 4:])

# %%
df
# Out:
#     uid                   name                                   url   height  \
# 0     1         Luke Skywalker   https://www.swapi.tech/api/people/1      172
# 1     2                  C-3PO   https://www.swapi.tech/api/people/2      167
# 2     3                  R2-D2   https://www.swapi.tech/api/people/3       96
# 3     4            Darth Vader   https://www.swapi.tech/api/people/4      202
# 4     5            Leia Organa   https://www.swapi.tech/api/people/5      150
# 5     6              Owen Lars   https://www.swapi.tech/api/people/6      178
# 6     7     Beru Whitesun lars   https://www.swapi.tech/api/people/7      165
# 7     8                  R5-D4   https://www.swapi.tech/api/people/8       97
# 8     9      Biggs Darklighter   https://www.swapi.tech/api/people/9      183
# 9    10         Obi-Wan Kenobi  https://www.swapi.tech/api/people/10      182
# 10   11       Anakin Skywalker  https://www.swapi.tech/api/people/11      188
# 11   12         Wilhuff Tarkin  https://www.swapi.tech/api/people/12      180
# 12   13              Chewbacca  https://www.swapi.tech/api/people/13      228
# 13   14               Han Solo  https://www.swapi.tech/api/people/14      180
# 14   15                 Greedo  https://www.swapi.tech/api/people/15      173
# 15   16  Jabba Desilijic Tiure  https://www.swapi.tech/api/people/16      175
# 16   18         Wedge Antilles  https://www.swapi.tech/api/people/18      170
# 17   19       Jek Tono Porkins  https://www.swapi.tech/api/people/19      180
# 18   20                   Yoda  https://www.swapi.tech/api/people/20       66
# 19   21              Palpatine  https://www.swapi.tech/api/people/21      170
# 20   22              Boba Fett  https://www.swapi.tech/api/people/22      183
# 21   23                  IG-88  https://www.swapi.tech/api/people/23      200
# 22   24                  Bossk  https://www.swapi.tech/api/people/24      190
# 23   25       Lando Calrissian  https://www.swapi.tech/api/people/25      177
# 24   26                  Lobot  https://www.swapi.tech/api/people/26      175
# 25   27                 Ackbar  https://www.swapi.tech/api/people/27      180
# 26   28             Mon Mothma  https://www.swapi.tech/api/people/28      150
# 27   29           Arvel Crynyd  https://www.swapi.tech/api/people/29  unknown
# 28   30  Wicket Systri Warrick  https://www.swapi.tech/api/people/30       88
#
#        mass hair_color    skin_color  eye_color birth_year   gender  \
# 0        77      blond          fair       blue      19BBY     male
# 1        75        NaN          gold     yellow     112BBY      NaN
# 2        32        NaN         white       blue        red    33BBY
# 3       136       none         white     yellow    41.9BBY     male
# 4        49      brown         light      brown      19BBY   female
# 5       120      brown          grey      light       blue    52BBY
# 6        75      brown         light       blue      47BBY   female
# 7        32        NaN         white        red        red  unknown
# 8        84      black         light      brown      24BBY     male
# 9        77     auburn         white       fair  blue-gray    57BBY
# 10       84      blond          fair       blue    41.9BBY     male
# 11  unknown     auburn          grey       fair       blue    64BBY
# 12      112      brown       unknown       blue     200BBY     male
# 13       80      brown          fair      brown      29BBY     male
# 14       74        NaN         green      black      44BBY     male
# 15        1        358           NaN  green-tan      brown   orange
# 16       77      brown          fair      hazel      21BBY     male
# 17      110      brown          fair       blue    unknown     male
# 18       17      white         green      brown     896BBY     male
# 19       75       grey          pale     yellow      82BBY     male
# 20     78.2      black          fair      brown    31.5BBY     male
# 21      140       none         metal        red      15BBY     none
# 22      113       none         green        red      53BBY     male
# 23       79      black          dark      brown      31BBY     male
# 24       79       none         light       blue      37BBY     male
# 25       83       none  brown mottle     orange      41BBY     male
# 26  unknown     auburn          fair       blue      48BBY   female
# 27  unknown      brown          fair      brown    unknown     male
# 28       20      brown         brown      brown       8BBY     male
#
#                             homeworld homeworld_name  rotation_period  \
# 0    https://swapi.info/api/planets/1       Tatooine             23.0
# 1    https://swapi.info/api/planets/1       Tatooine             23.0
# 2                                 NaN            NaN              NaN
# 3    https://swapi.info/api/planets/1       Tatooine             23.0
# 4    https://swapi.info/api/planets/2       Alderaan             24.0
# 5                                male            NaN              NaN
# 6    https://swapi.info/api/planets/1       Tatooine             23.0
# 7                                 NaN            NaN              NaN
# 8    https://swapi.info/api/planets/1       Tatooine             23.0
# 9                                male            NaN              NaN
# 10   https://swapi.info/api/planets/1       Tatooine             23.0
# 11                               male            NaN              NaN
# 12  https://swapi.info/api/planets/14       Kashyyyk             26.0
# 13  https://swapi.info/api/planets/22       Corellia             25.0
# 14  https://swapi.info/api/planets/23          Rodia             29.0
# 15                             600BBY            NaN              NaN
# 16  https://swapi.info/api/planets/22       Corellia             25.0
# 17  https://swapi.info/api/planets/26     Bestine IV             26.0
# 18  https://swapi.info/api/planets/28        unknown              0.0
# 19   https://swapi.info/api/planets/8          Naboo             26.0
# 20  https://swapi.info/api/planets/10         Kamino             27.0
# 21  https://swapi.info/api/planets/28        unknown              0.0
# 22  https://swapi.info/api/planets/29      Trandosha             25.0
# 23  https://swapi.info/api/planets/30        Socorro             20.0
# 24   https://swapi.info/api/planets/6         Bespin             12.0
# 25  https://swapi.info/api/planets/31       Mon Cala             21.0
# 26  https://swapi.info/api/planets/32      Chandrila             20.0
# 27  https://swapi.info/api/planets/28        unknown              0.0
# 28   https://swapi.info/api/planets/7          Endor             18.0
#
#     orbital_period  diameter    climate  \
# 0            304.0   10465.0       arid
# 1            304.0   10465.0       arid
# 2              NaN       NaN        NaN
# 3            304.0   10465.0       arid
# 4            364.0   12500.0  temperate
# 5              NaN       NaN        NaN
# 6            304.0   10465.0       arid
# 7              NaN       NaN        NaN
# 8            304.0   10465.0       arid
# 9              NaN       NaN        NaN
# 10           304.0   10465.0       arid
# 11             NaN       NaN        NaN
# 12           381.0   12765.0   tropical
# 13           329.0   11000.0  temperate
# 14           305.0    7549.0        hot
# 15             NaN       NaN        NaN
# 16           329.0   11000.0  temperate
# 17           680.0    6400.0  temperate
# 18             0.0       0.0    unknown
# 19           312.0   12120.0  temperate
# 20           463.0   19720.0  temperate
# 21             0.0       0.0    unknown
# 22           371.0       0.0       arid
# 23           326.0       0.0       arid
# 24          5110.0  118000.0  temperate
# 25           398.0   11030.0  temperate
# 26           368.0   13500.0  temperate
# 27             0.0       0.0    unknown
# 28           402.0    4900.0  temperate
#
#                                    gravity  \
# 0                               1 standard
# 1                               1 standard
# 2                                      NaN
# 3                               1 standard
# 4                               1 standard
# 5                                      NaN
# 6                               1 standard
# 7                                      NaN
# 8                               1 standard
# 9                                      NaN
# 10                              1 standard
# 11                                     NaN
# 12                              1 standard
# 13                              1 standard
# 14                              1 standard
# 15                                     NaN
# 16                              1 standard
# 17                                 unknown
# 18                                 unknown
# 19                              1 standard
# 20                              1 standard
# 21                                 unknown
# 22                           0.62 standard
# 23                              1 standard
# 24  1.5 (surface), 1 standard (Cloud City)
# 25                                       1
# 26                                       1
# 27                                 unknown
# 28                           0.85 standard
#
#                                      terrain surface_water   population
# 0                                     desert             1       200000
# 1                                     desert             1       200000
# 2                                        NaN           NaN          NaN
# 3                                     desert             1       200000
# 4                      grasslands, mountains            40   2000000000
# 5                                        NaN           NaN          NaN
# 6                                     desert             1       200000
# 7                                        NaN           NaN          NaN
# 8                                     desert             1       200000
# 9                                        NaN           NaN          NaN
# 10                                    desert             1       200000
# 11                                       NaN           NaN          NaN
# 12            jungle, forests, lakes, rivers            60     45000000
# 13             plains, urban, hills, forests            70   3000000000
# 14            jungles, oceans, urban, swamps            60   1300000000
# 15                                       NaN           NaN          NaN
# 16             plains, urban, hills, forests            70   3000000000
# 17                     rocky islands, oceans            98     62000000
# 18                                   unknown       unknown      unknown
# 19  grassy hills, swamps, forests, mountains            12   4500000000
# 20                                     ocean           100   1000000000
# 21                                   unknown       unknown      unknown
# 22      mountains, seas, grasslands, deserts       unknown     42000000
# 23                        deserts, mountains       unknown    300000000
# 24                                 gas giant             0      6000000
# 25                    oceans, reefs, islands           100  27000000000
# 26                           plains, forests            40   1200000000
# 27                                   unknown       unknown      unknown
# 28                 forests, mountains, lakes             8     30000000

# %%
df.to_csv(".\data\swapi_all_merged.csv", index=False)
